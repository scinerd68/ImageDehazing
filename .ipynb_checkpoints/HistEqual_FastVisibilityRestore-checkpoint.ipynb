# %% [markdown]
# # Dataset

# %% [markdown]
# <b> Uncomment the below codes if running on Google Colab

# %% [markdown]
# @article{li2019benchmarking,
# title={Benchmarking Single-Image Dehazing and Beyond},
# author={Li, Boyi and Ren, Wenqi and Fu, Dengpan and Tao, Dacheng and Feng, Dan and Zeng, Wenjun and Wang, Zhangyang},
# journal={IEEE Transactions on Image Processing},
# volume={28},
# number={1},
# pages={492--505},
# year={2019},
# publisher={IEEE}
# }

# %%
# ! pip install -q kaggle

# %% [markdown]
# Download kaggle.json (contains Kaggle's personal API key)

# %%
# ! gdown 16n_UWvGFBtK0r05zO9BQqd9UxLHrP1nR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16n_UWvGFBtK0r05zO9BQqd9UxLHrP1nR
# To: /content/kaggle.json
# 100% 68.0/68.0 [00:00<00:00, 87.9kB/s]

# %%
# ! mkdir ~/.kaggle

# ! cp kaggle.json ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# ! chmod 600 ~/.kaggle/kaggle.json

# %%
# ! kaggle datasets download -d balraj98/synthetic-objective-testing-set-sots-reside
# Out:
# synthetic-objective-testing-set-sots-reside.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
# kaggle.json  sample_data  sots	synthetic-objective-testing-set-sots-reside.zip

# %%
# ! mkdir sots
# Out:
# mkdir: cannot create directory ‘sots’: File exists

# %%
# ! unzip -o synthetic-objective-testing-set-sots-reside.zip -d sots
# Out:
# Archive:  synthetic-objective-testing-set-sots-reside.zip
#   inflating: sots/indoor/clear/1400.png
#   inflating: sots/indoor/clear/1401.png
#   inflating: sots/indoor/clear/1402.png
#   inflating: sots/indoor/clear/1403.png
#   inflating: sots/indoor/clear/1404.png
#   inflating: sots/indoor/clear/1405.png
#   inflating: sots/indoor/clear/1406.png
#   inflating: sots/indoor/clear/1407.png
#   inflating: sots/indoor/clear/1408.png
#   inflating: sots/indoor/clear/1409.png
#   inflating: sots/indoor/clear/1410.png
#   inflating: sots/indoor/clear/1411.png
#   inflating: sots/indoor/clear/1412.png
#   inflating: sots/indoor/clear/1413.png
#   inflating: sots/indoor/clear/1414.png
#   inflating: sots/indoor/clear/1415.png
#   inflating: sots/indoor/clear/1416.png
#   inflating: sots/indoor/clear/1417.png
#   inflating: sots/indoor/clear/1418.png
#   inflating: sots/indoor/clear/1419.png
#   inflating: sots/indoor/clear/1420.png
#   inflating: sots/indoor/clear/1421.png
# ...

# %%
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
from PIL import Image
from PIL import ImageFilter
font = cv2.FONT_HERSHEY_COMPLEX

# %%
IMG = '/images/0288_0.95_0.2.jpg'

# %%
# IMG = '/content/sots/outdoor/hazy/0288_0.95_0.2.jpg'

# %% [markdown]
# # Functions

# %% [markdown]
# ## Histogram equalization

# %%
def histEqual_BGR(img_path):
    '''
    perform vanilla histogram equalization seperately on each of the 3 B-G-R color channels.
    :param img_path: String, path to BGR Image
    :return: transformed BGR image
    '''
    img = cv2.imread(img_path)
    bgr_planes = cv2.split(img)
    for i in range(3):
        bgr_planes[i] = cv2.equalizeHist(bgr_planes[i])
    he = cv2.merge(bgr_planes)
    return he

def histEqual_HSV(img_path, equalize_S = True, equalize_V = True):
    '''
    Convert BGR image to HSV image, perform vanilla histogram equalization
    on Saturation and/or Value channel of HSV image, then convert back to BGR image.

    :param img_path: String, path to BGR Image
    :param equalize_S: Boolean, if True, perform HE on Saturation channel
    :param equalize_V:  Boolean, if True, perform HE on Value channel
    :return: transformed BGR image
    '''
    img = cv2.imread(IMG)
    hsv_planes = cv2.split(cv2.cvtColor(img, cv2.COLOR_BGR2HSV))

    if equalize_S:
        hsv_planes[1] = cv2.equalizeHist(hsv_planes[1])
    if equalize_V:
        hsv_planes[2] = cv2.equalizeHist(hsv_planes[2])

    he_hsv = cv2.merge(hsv_planes)
    he_hsv = cv2.cvtColor(he_hsv, cv2.COLOR_HSV2BGR)
    return he_hsv

# %% [markdown]
# ## CLAHE

# %%
def clahe_BGR(img_path):
    '''
    perform contrast limited adaptive histogram equalization (CLAHE) seperately
    on each of the 3 B-G-R color channels.
    :param img_path: String, path to BGR Image
    :return: transformed BGR image
    '''
    img = cv2.imread(img_path)
    bgr_planes = cv2.split(img)
    for i in range(3):
        clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
        bgr_planes[i] = clahe.apply(bgr_planes[i])
    clh = cv2.merge(bgr_planes)
    return clh

def clahe_HSV(img_path, clipLimit = 3.0, tileGridSize = (8,8), equalize_S = True, equalize_V = True):
    '''
    Convert BGR image to HSV image, perform CLAHE on Saturation and/or Value
    channel of HSV image, then convert back to BGR image.

    :param img_path: String, path to BGR Image
    :param equalize_S: Boolean, if True, perform CLAHE on Saturation channel
    :param equalize_V:  Boolean, if True, perform CLAHE on Value channel
    :return: transformed BGR image
    '''
    img = cv2.imread(img_path)
    hsv_planes = cv2.split(cv2.cvtColor(img, cv2.COLOR_BGR2HSV))
    clahe = cv2.createCLAHE(clipLimit=clipLimit, tileGridSize=tileGridSize)
    if equalize_S:
        hsv_planes[1] = clahe.apply(hsv_planes[1])
    if equalize_V:
        hsv_planes[2] = clahe.apply(hsv_planes[2])

    clh_hsv = cv2.merge(hsv_planes)
    clh_hsv = cv2.cvtColor(clh_hsv, cv2.COLOR_HSV2BGR)

    return clh_hsv

# %% [markdown]
# ## Visibility restoration

# %%
import cv2
import numpy as np
from PIL import Image
from PIL import ImageFilter

def colorCorrect(img,u):
    '''
    perform color correction on BGR image (details in report)
    :param img: BGR Image
    :return: color corrected BGR image
    '''
    img = np.float64(img) / 255
    B_rmse = np.std(img[:,:,0])
    G_rmse = np.std(img[:,:,1])
    R_rmse = np.std(img[:,:,2])

    B_max = np.mean(img[:,:,0]) + u * B_rmse
    G_max = np.mean(img[:,:,1]) + u * G_rmse
    R_max = np.mean(img[:,:,2]) + u * R_rmse

    B_min = np.mean(img[:,:,0]) - u * B_rmse
    G_min = np.mean(img[:,:,1]) - u * G_rmse
    R_min = np.mean(img[:,:,2]) - u * R_rmse

    B_cr = (img[:,:,0]  - B_min) / (B_max - B_min)
    G_cr = (img[:,:,1]  - G_min) / (G_max - G_min)
    R_cr = (img[:,:,2]  - R_min) / (R_max - R_min)

    img_CR = cv2.merge([B_cr,G_cr,R_cr]) *255
    img_CR = np.clip(img_CR,0,255)
    img_CR = np.uint8(img_CR)

    return img_CR


def getMinChannel(img):
    '''
    get local min of single-channel image
    :param img: single-channel Image
    :return: local-min image that has the same shape as the input image
    '''
    imgGray = np.zeros((img.shape[0],img.shape[1]),np.float32)
    for i in range(img.shape[0]):
      for j in range(img.shape[1]):
        localMin = 255
        for k in range(2):
          if img.item((i,j,k)) < localMin:
            localMin = img.item((i,j,k))
        imgGray[i,j] = localMin
    return imgGray


def whiteBalance(img):
    '''
    perform white balancing on BGR Image (details in report)
    :param img: BGR Image
    :return: white balanced BGR image
    '''
    B, G, R = np.double(img[:, :, 0]), np.double(img[:, :, 1]), np.double(img[:, :, 2])
    B_ave, G_ave, R_ave = np.mean(B), np.mean(G), np.mean(R)
    K = (B_ave + G_ave + R_ave) / 3
    Kb, Kg, Kr = K / B_ave, K / G_ave, K / R_ave
    Ba = (B * Kb)
    Ga = (G * Kg)
    Ra = (R * Kr)

    for i in range(len(Ba)):
        for j in range(len(Ba[0])):
            Ba[i][j] = 255 if Ba[i][j] > 255 else Ba[i][j]
            Ga[i][j] = 255 if Ga[i][j] > 255 else Ga[i][j]
            Ra[i][j] = 255 if Ra[i][j] > 255 else Ra[i][j]

    # print(np.mean(Ba), np.mean(Ga), np.mean(Ra))
    dst_img = np.uint8(np.zeros_like(img))
    dst_img[:, :, 0] = Ba
    dst_img[:, :, 1] = Ga
    dst_img[:, :, 2] = Ra
    return dst_img


def visibilityRestore(img_path, s_v = 5, p = 0.95, color_correct = True):
    '''
    full pipeline of visibility restoration algorithm
    :param img_path: path to BGR Image
    :param s_v: Median filters' kernel size
    :param p: interpreted as the "percentage" of fog to be filtered, ranged 0 to 1, the higher, the
    higher the effect of restoration.
    :param color_correct: Boolean, whether to apply color correcting on the result image or not.
    :return: restored BGR image
    '''
    img = cv2.imread(img_path)
    
    img_wb =whiteBalance(img)

    W = getMinChannel(img_wb)
  
    A = cv2.medianBlur(np.uint8(W),s_v)
    B = W - A
    B = np.abs(B)
    B = A - cv2.medianBlur(np.uint8(B),s_v)
    max_255_img = np.ones(B.shape,dtype = np.uint8 ) * 255
    min_t = cv2.merge([np.uint8(p*B),np.uint8(W),max_255_img])
    min_t = getMinChannel(min_t)
    min_t[min_t<0] = 0
    V = np.uint8(min_t)
    # V = cv2.blur(V,(s_v, s_v))

    V = np.float32(V) / 255

    R_dehazy = np.zeros((V.shape[0],V.shape[1],3), dtype=np.float32)

    img_wb = np.float32(img_wb) / 255

    for i in range(3):
        R_dehazy[:,:,i] = (img_wb[:,:,i] - V) / (1 - V)
    R_dehazy = R_dehazy / R_dehazy.max()

    R_dehazy = np.clip(R_dehazy,0,1)
    R_dehazy = np.uint8(R_dehazy*255)

    if color_correct:
        R_dehazy = colorCorrect(R_dehazy,2)

    return R_dehazy

# %% [markdown]
# # Histogram Equalization

# %% [markdown]
# We compare:
# * HE on B,G,R of BGR image
# * HE on V of HSV image
# * HE on S, V of HSV image

# %%
he_bgr = histEqual_BGR(IMG)
he_v = histEqual_HSV(IMG, equalize_S = False)
he_sv = histEqual_HSV(IMG)

# %%
og = cv2.imread(IMG)
h, w = og.shape[:2]
result = np.zeros([h*2, w*2, 3], dtype=og.dtype)
result[0:h,0:w,:] = og
result[0:h,w:2*w,:] = he_bgr
result[h:h*2,0:w,:] = he_v
result[h:h*2,w:2*w,:] = he_sv
cv2.putText(result, "original", (10, 30), font, 1.0, (0, 0, 255), 2)
cv2.putText(result, "HE_BGR", (w+10, 30), font, 1.0, (0, 0, 255), 2)
cv2.putText(result, "HE_V", (10, h+30), font, 1.0, (0, 0, 255), 2)
cv2.putText(result, "HE_SV", (w+10, h+30), font, 1.0, (0, 0, 255), 2)
#cv_show('dehazy',result)

cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x826 at 0x7FB5560974D0>

# %% [markdown]
# # CLAHE

# %% [markdown]
# We compare:
# * CLAHE on B,G,R of BGR image
# * CLAHE on V of HSV image
# * CLAHE on S, V of HSV image

# %%
clh_bgr = clahe_BGR(IMG)
clh_v = clahe_HSV(IMG, equalize_S = False)
clh_sv = clahe_HSV(IMG)

# %%
og = cv2.imread(IMG)
h, w = og.shape[:2]
result = np.zeros([h*2, w*2, 3], dtype=og.dtype)
result[0:h,0:w,:] = og
result[0:h,w:2*w,:] = clh_bgr
result[h:h*2,0:w,:] = clh_v
result[h:h*2,w:2*w,:] = clh_sv
cv2.putText(result, "original", (10, 30), font, 1.0, (0, 0, 255), 2)
cv2.putText(result, "CLAHE_BGR", (w+10, 30), font, 1.0, (0, 0, 255), 2)
cv2.putText(result, "CLAHE_V", (10, h+30), font, 1.0, (0, 0, 255), 2)
cv2.putText(result, "CLAHE_SV", (w+10, h+30), font, 1.0, (0, 0, 255), 2)
#cv_show('dehazy',result)

cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=1100x826 at 0x7FB5462B7650>

# %% [markdown]
# # Fast Visibility Restoration from a Single Color or Gray Level Image

# %% [markdown]
# We compare:
# * Restored image
# * Restored image with Color correction
#
# with these values of *p*:
# * 0.7
# * 0.8
# * 0.9

# %%
p_values = [0.7,0.8,0.9]

og = cv2.imread(IMG)
h, w = og.shape[:2]
result = np.zeros([h*4, w*2, 3], dtype=og.dtype)
result[0:h,0:w,:] = og
cv2.putText(result, "original", (10, 30), font, 1.0, (0, 0, 255), 2)

for i in range(1,4):
    restored = visibilityRestore(IMG, s_v = 5, p = p_values[i-1], color_correct = False)
    color_corrected = colorCorrect(restored, u = 2)
    result[h*i:h*(i+1),0:w,:] = restored
    result[h*i:h*(i+1),w:2*w,:] = color_corrected
    
    cv2.putText(result, "restored, p = "+str(p_values[i-1]), (10, h*i+30), font, 0.5, (0, 0, 255), 2)
    cv2.putText(result, "restored & color corrected, p = "+str(p_values[i-1]), (10 + w, h*i+30), font, 0.5, (0, 0, 255), 2)

cv2_imshow(result)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
